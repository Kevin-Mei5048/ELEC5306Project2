# %% [markdown]
# A Deep Learning Toy Model for Image Compression
# ===
#
# In this project, we will use simple deep learning networks for basic image compression.
#
# You will get familiar with:
#
# * train/test a simple deep learning model (for image compression in this project) with PyTorch library
# * hyper-parameter tuning for deep learning model
# * collect and analyse the training loss and metrics
# * evaluate and visualize the result
#
# ## 1. Objectives
# 1. Train a baseline neural network.
# 2. Plot the loss-epoch curve.
# 3. Tune learning rate, the depth of the network, and different layers. Then compare the results in SSIM, PSNR.
# 4. Visualize some cases.
# 5. Customize your model (and loss, learning rate, scheduler, etc) for better performance.

# %% [markdown]
# ## Get GPU ready
#
# Change Runtime Type in the Colab menu to 'GPU'.

# %% [markdown]
# ## Prepare the data
#
# The data for training/test is at https://drive.google.com/drive/folders/1Ry2G14vY6uWoSG1rilvZOmNLvl3cOSUv?usp=sharing
#
# 1. Put this folder (and the data inside of course) in your GoogleDrive.
# 2. Run the command below to mount the GoogleDrive onto Colab.
# 3. Check the path to the data (e.g. `'/content/drive/MyDrive/MYDATA'`), and we will use this later.
#
# Hint: you can check the file with either bash command or use the leftmost sidebar in Colab, there's a folder shaped icon.

# %% [markdown]
# **Note**: If you store the dataset in Google Drive, accessing the data might be slow due to Google Drive's limitations. Alternatively, you can upload the dataset to Colab's local runtime environment by clicking the '**Files**' button on the left sidebar. This approach can enhance data access speed during the session. However, please be aware that any data uploaded locally will be removed once you restart or exit the Colab session. To avoid data loss, consider reloading the data at the beginning of each session, or consistently use Google Drive mounting to manage your data.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Check the data: When you do `!ls YOUR_DATA_PATH`, you should see `train` and `valid` under the dir.

# %%
# cd drive/MyDrive/ELEC5306/
# !cd '/Users/harryk/Documents/usyd/2024sem1/ELEC5306/project2'

# %% [markdown]
# ## 1.1 Code Template
# But feel free to modify if you think it's needed.

# %% [markdown]
# Let's first import packages for this project. You are not required to make modifications to this. But if you are using any other packages that's not included, feel free to import anytime.

# %%
# ################################################
# import packages

import argparse
import math
import random
import shutil
import sys

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader
from torchvision import transforms


from pathlib import Path

from PIL import Image
from torch.utils.data import Dataset

import time

import matplotlib.pyplot as plt

# %% [markdown]
# Then we define a Dataset class that could iterate over images under a directory (`root/split`).
#
# You are not required to make modifications to this.

# %%
import PIL
from pathlib import Path
import PIL.Image
from torch.utils.data import Dataset

# ################################################
# define our Dataset class

class ImageFolder(Dataset):
    """Load an image folder database. Training and testing image samples
    are respectively stored in separate directories:

    .. code-block::

        - rootdir/
            - train/
                - img000.png
                - img001.png
                ...
            - valid/
                - img000.png
                - img001.png
                ...

    Args:
        root (string): root directory of the dataset
        transform (callable, optional): a function or transform that takes in a
            PIL image and returns a transformed version
        split (string): split mode ('train' or 'val')
    """

    def __init__(self, root, transform=None, split="train"):
        splitdir = Path(root) / split

        if not splitdir.is_dir():
            raise RuntimeError(f'Invalid directory "{root}"')

        self.samples = [f for f in splitdir.iterdir() if f.is_file()]

        self.transform = transform

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            img: `PIL.Image.Image` or transformed `PIL.Image.Image`.
        """
        img = PIL.Image.open(self.samples[index]).convert("RGB")
        if self.transform:
            return self.transform(img)
        return img

    def __len__(self):
        return len(self.samples)

# %% [markdown]
# Then let's define a baseline neural network.

# %%
# ###################################################
# a baseline model

def conv(in_channels, out_channels, kernel_size=5, stride=2):
    return nn.Conv2d(
        in_channels,
        out_channels,
        kernel_size=kernel_size,
        stride=stride,
        padding=kernel_size // 2,
    )


def deconv(in_channels, out_channels, kernel_size=5, stride=2):
    return nn.ConvTranspose2d(
        in_channels,
        out_channels,
        kernel_size=kernel_size,
        stride=stride,
        output_padding=stride - 1,
        padding=kernel_size // 2,
    )


class Network(nn.Module):

    def __init__(self, N, M, init_weights=True, **kwargs):
        super().__init__(**kwargs)

        self.g_a = nn.Sequential(
            conv(3, N),
            conv(N, N),
            conv(N, N),
            conv(N, M),
        )

        self.g_s = nn.Sequential(
            deconv(M, N),
            deconv(N, N),
            deconv(N, N),
            deconv(N, 3),
        )

        self.N = N
        self.M = M

        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        y = self.g_a(x)
        x_hat = self.g_s(y)

        return {
            "x_hat": x_hat,
        }

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def compress(self, x):
        y = self.g_a(x)
        return y

    def decompress(self, y_hat):
        x_hat = self.g_s(y_hat).clamp_(0, 1)
        return {"x_hat": x_hat}

# %% [markdown]
# Let's check if this network structure works fine with data flow.

# %%
# 1. get some random data
data = torch.zeros((1, 3, 128, 128))
# 2. get a random instance of the model class
model = Network(5, 5)
# 3. forward the data to the model
preds = model(data)
# 4. do compress
compressed = model.compress(data)
# 5. decompress
data_hat = model.decompress(compressed)

# %% [markdown]
# If there's no error pops out in the last code cell, then our network is fine.
#
# We can compute the compression ratio of this network

# %%
print('compression ratio: compressed/original {}'.format(compressed.numel() / data.numel()))
# Out:
# compression ratio: compressed/original 0.006510416666666667

# %% [markdown]
# The compression ratio of this random network is suprising, but we don't expect any good performance as the model is too small.
#
# Usually the larger the model, the better the performance given sufficient training data and iterations.

# %% [markdown]
# Let's move on to the loss, average meter, and optimizer.
#
# A good thing about this task is we don't need extra label but the input image.
#
# The loss is simply compared between the decoded image and the original one.

# %%
class Loss(nn.Module):

    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, output, target):
        out = {}
        out["mse_loss"] = self.mse(output["x_hat"], target)
        out["loss"] = out["mse_loss"] * 255

        return out

# %%
class AverageMeter:
    """Compute running average."""

    def __init__(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def configure_optimizers(net, learning_rate):

    optimizer = optim.Adam(
        net.parameters(),
        lr=learning_rate,
    )

    return optimizer

# %%
def save_checkpoint(state, is_best, filename="checkpoint.pth.tar"):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, "checkpoint_best_loss.pth.tar")

# %% [markdown]
# After we almost got everything we need, we define a `train_one_epoch` function for training the model for one epoch.

# %%
def train_one_epoch(
    model, criterion, train_dataloader, optimizer, epoch, clip_max_norm
):
    model.train()
    device = next(model.parameters()).device

    for i, d in enumerate(train_dataloader):
        d = d.to(device)

        optimizer.zero_grad()

        out_net = model(d)

        out_criterion = criterion(out_net, d)
        out_criterion["loss"].backward()
        if clip_max_norm > 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), clip_max_norm)
        optimizer.step()

        if i % 10 == 0:
            print(
                f"Train epoch {epoch}: ["
                f"{i*len(d)}/{len(train_dataloader.dataset)}"
                f" ({100. * i / len(train_dataloader):.0f}%)]"
                f'\tLoss: {out_criterion["loss"].item():.3f} |'
                f'\tMSE loss: {out_criterion["mse_loss"].item():.3f}'
            )

# %% [markdown]
# Likewise we further define a `test_epoch` function for getting the error on a valid set.
#
# This part of data is not used in the training process, and will only be used to check the performance and give us implications of the performance of the model on unseen data.
#
# This function returns the average loss on the valid split data.

# %%
def test_epoch(epoch, test_dataloader, model, criterion):
    model.eval()
    device = next(model.parameters()).device

    loss = AverageMeter()
    mse_loss = AverageMeter()

    with torch.no_grad():
        for d in test_dataloader:
            d = d.to(device)
            out_net = model(d)
            d_out = out_net['x_hat']
            out_criterion = criterion(out_net, d)

            loss.update(out_criterion["loss"])
            mse_loss.update(out_criterion["mse_loss"])

    print(
        f"Test epoch {epoch}: Average losses:"
        f"\tLoss: {loss.avg:.3f} |"
        f"\tMSE loss: {mse_loss.avg:.3f}\n"
    )

    return loss.avg

# %% [markdown]
# Finally we define a main function, and complete the whole training/testing process.
#
# At the start of this main function, we define some arguments that's useful for training.

# %% [markdown]
# Define some arguments useful for training/validation.

# %%
seed = 123                                        # for reproducibility
cuda = True                                       # use GPU
save = True                                       # save trained model
dataset = 'C:\somethings\Kevin'       # path to the root of the dataset Modify this if you change the path
checkpoint = ''                                   # load pretrained model
epochs = 10                                       # total training epochs
num_workers = 0                                  # multi-process for loading training data
clip_max_norm = 1.0                               # avoid gradient explosion
patch_size = (256, 256)                           # input size for the training network
learning_rate = 1e-4
batch_size = 16
test_batch_size = 16
N = 128
M = 192

# %%
torch.manual_seed(seed)
random.seed(seed)

train_transforms = transforms.Compose(
    [transforms.RandomCrop(patch_size), transforms.ToTensor()]
)

test_transforms = transforms.Compose(
    [transforms.CenterCrop(patch_size), transforms.ToTensor()]
)

train_dataset = ImageFolder(dataset, split="train", transform=train_transforms)
test_dataset = ImageFolder(dataset, split="valid", transform=test_transforms)

device = "cuda" if cuda and torch.cuda.is_available() else "cpu"

#0423log: device is False cause "torch.cuda.is_available()" is False
#log: install the fit cuda, cudnn. 

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    shuffle=True,
    pin_memory=(device == "cuda")
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    num_workers=num_workers,
    shuffle=False,
    pin_memory=(device == "cuda")
)

net = Network(N, M)
net = net.to(device)
print("training on", device)

optimizer = configure_optimizers(net, learning_rate)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
criterion = Loss()

last_epoch = 0
if checkpoint:  # load from previous checkpoint
    print("Loading", checkpoint)
    checkpoint = torch.load(checkpoint, map_location=device)
    last_epoch = checkpoint["epoch"] + 1
    net.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    lr_scheduler.load_state_dict(checkpoint["lr_scheduler"])

best_loss = float("inf")
start = time.time()
for epoch in range(last_epoch, epochs):
    print(f"Learning rate: {optimizer.param_groups[0]['lr']}")
    train_one_epoch(
        net,
        criterion,
        train_dataloader,
        optimizer,
        epoch,
        clip_max_norm,
    )
    loss = test_epoch(epoch, test_dataloader, net, criterion)
    lr_scheduler.step(loss)

    is_best = loss < best_loss
    best_loss = min(loss, best_loss)

    if save:
        save_checkpoint(
            {
                "epoch": epoch,
                "state_dict": net.state_dict(),
                "loss": loss,
                "optimizer": optimizer.state_dict(),
                "lr_scheduler": lr_scheduler.state_dict(),
            },
            is_best,
        )
print(f"finished training in {round(time.time()-start)} seconds")
# Out:
# training on cuda
# Learning rate: 0.0001
# Train epoch 0: [0/250 (0%)]	Loss: 3247.637 |	MSE loss: 12.736
# Train epoch 0: [160/250 (62%)]	Loss: 191.244 |	MSE loss: 0.750
# Test epoch 0: Average losses:	Loss: 98.123 |	MSE loss: 0.385
#
# Learning rate: 0.0001
# Train epoch 1: [0/250 (0%)]	Loss: 99.869 |	MSE loss: 0.392
# Train epoch 1: [160/250 (62%)]	Loss: 45.492 |	MSE loss: 0.178
# Test epoch 1: Average losses:	Loss: 48.158 |	MSE loss: 0.189
#
# Learning rate: 0.0001
# Train epoch 2: [0/250 (0%)]	Loss: 47.353 |	MSE loss: 0.186
# Train epoch 2: [160/250 (62%)]	Loss: 33.615 |	MSE loss: 0.132
# Test epoch 2: Average losses:	Loss: 32.154 |	MSE loss: 0.126
#
# Learning rate: 0.0001
# Train epoch 3: [0/250 (0%)]	Loss: 20.406 |	MSE loss: 0.080
# Train epoch 3: [160/250 (62%)]	Loss: 11.288 |	MSE loss: 0.044
# Test epoch 3: Average losses:	Loss: 21.860 |	MSE loss: 0.086
#
# Learning rate: 0.0001
# Train epoch 4: [0/250 (0%)]	Loss: 18.311 |	MSE loss: 0.072
# Train epoch 4: [160/250 (62%)]	Loss: 11.628 |	MSE loss: 0.046
# Test epoch 4: Average losses:	Loss: 16.714 |	MSE loss: 0.066
#
# Learning rate: 0.0001
# Train epoch 5: [0/250 (0%)]	Loss: 13.916 |	MSE loss: 0.055
# Train epoch 5: [160/250 (62%)]	Loss: 23.141 |	MSE loss: 0.091
# Test epoch 5: Average losses:	Loss: 12.785 |	MSE loss: 0.050
#
# Learning rate: 0.0001
# Train epoch 6: [0/250 (0%)]	Loss: 23.377 |	MSE loss: 0.092
# Train epoch 6: [160/250 (62%)]	Loss: 6.007 |	MSE loss: 0.024
# Test epoch 6: Average losses:	Loss: 11.398 |	MSE loss: 0.045
#
# Learning rate: 0.0001
# Train epoch 7: [0/250 (0%)]	Loss: 14.422 |	MSE loss: 0.057
# Train epoch 7: [160/250 (62%)]	Loss: 7.812 |	MSE loss: 0.031
# Test epoch 7: Average losses:	Loss: 9.279 |	MSE loss: 0.036
#
# Learning rate: 0.0001
# Train epoch 8: [0/250 (0%)]	Loss: 8.954 |	MSE loss: 0.035
# Train epoch 8: [160/250 (62%)]	Loss: 7.313 |	MSE loss: 0.029
# Test epoch 8: Average losses:	Loss: 8.042 |	MSE loss: 0.032
#
# Learning rate: 0.0001
# Train epoch 9: [0/250 (0%)]	Loss: 5.082 |	MSE loss: 0.020
# Train epoch 9: [160/250 (62%)]	Loss: 9.020 |	MSE loss: 0.035
# Test epoch 9: Average losses:	Loss: 7.117 |	MSE loss: 0.028
#
# finished training in 219 seconds

# %%
# visualization
import matplotlib.pyplot as plt

dataset = 'C:\somethings\Kevin' # Modify this if you change the path
test_dataset = ImageFolder(dataset, split="valid", transform=transforms.ToTensor())
image = test_dataset[1].unsqueeze(0).to(device)
net.load_state_dict(torch.load('checkpoint_best_loss.pth.tar', map_location=device)["state_dict"])
predicted = net(image)['x_hat'].squeeze(0).detach()

fig, axes = plt.subplots(1,2)
axes[0].imshow(image.squeeze(0).cpu().permute(1, 2, 0))
axes[0].axis('off')
axes[0].set_title('original')
axes[1].imshow(predicted.cpu().permute(1, 2, 0))
axes[1].axis('off')
axes[1].set_title('compressed-decoded')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'compressed-decoded')

# %% [markdown]
# ## 1.2 PSNR as AverageMeter for testing

# %% [markdown]
# A scratch example of PSNR, no guarantee of working.
#
# Free to grab online.

# %%
def PSNR(img1, img2):
    # img1 and img2 within range [0, 1]
    img1, img2 = img1.detach(), img2.detach()
    img1 = img1 * 255
    img2 = img2 * 255
    batch_size = img1.shape[0]
    img1 = img1.reshape(batch_size, -1)
    img2 = img2.reshape(batch_size, -1)
    mse = torch.mean((img1 - img2) ** 2)
    return torch.mean(20 * torch.log10(255.0 / torch.sqrt(mse)))

# %% [markdown]
# A scratch example of SSIM, details are at https://github.com/VainF/pytorch-msssim

# %%
# !pip install pytorch-msssim

# %%
import torch
from pytorch_msssim import ssim

# X: (N,3,H,W) a batch of non-negative RGB images (0~1)
# Y: (N,3,H,W)

X = torch.randn((2, 3, 10, 10))
Y = torch.randn((2, 3, 10, 10))

X = X * 255
Y = Y * 255

# calculate ssim & ms-ssim for each image
ssim_val = ssim(X, Y, data_range=255, size_average=False) # return (N,)
print(ssim_val)
# Out:
# tensor([0.0010, 0.0571])
# c:\ProgramData\anaconda3\Lib\site-packages\pytorch_msssim\ssim.py:50: UserWarning: Skipping Gaussian Smoothing at dimension 2+0 for input: torch.Size([2, 3, 10, 10]) and win size: 11
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\pytorch_msssim\ssim.py:50: UserWarning: Skipping Gaussian Smoothing at dimension 2+1 for input: torch.Size([2, 3, 10, 10]) and win size: 11
#   warnings.warn(

# %% [markdown]
# Your code here:

# %%
def test_epoch(epoch, test_dataloader, model, criterion):
    model.eval()
    device = next(model.parameters()).device

    loss = AverageMeter()
    mse_loss = AverageMeter()
    psnr = AverageMeter()
    ssim_avg = AverageMeter()

    with torch.no_grad():
        for d in test_dataloader:
            d = d.to(device)
            out_net = model(d)
            d_out = out_net['x_hat']
            out_criterion = criterion(out_net, d)

            loss.update(out_criterion["loss"])
            mse_loss.update(out_criterion["mse_loss"])
            psnr.update(PSNR(d_out, d))
            ssim_avg.update(ssim(d * 255, d_out * 255, data_range=255, size_average=True))

    print(
        f"Test epoch {epoch}: Average losses:"
        f"\tLoss: {loss.avg:.3f} |"
        f"\tMSE loss: {mse_loss.avg:.3f} |"
        f"\tPSNR: {psnr.avg:.3f} |"
        f"\tSSIM: {ssim_avg.avg:.3f}\n"
    )

    return loss.avg

# do the test on valid split
test_epoch(10, test_dataloader, net, criterion)
# Out:
# Test epoch 10: Average losses:	Loss: 7.117 |	MSE loss: 0.028 |	PSNR: 15.543 |	SSIM: 0.158
# tensor(7.1173, device='cuda:0')

# %% [markdown]
# ## 1.3 Loss-Epoch curve

# %% [markdown]
# A naive example, no guarantee of working.

# %%
# import matplotlib.pyplot as plt

loss_epoch = list()
start = time.time()
for epoch in range(last_epoch, epochs):
    print(f"Learning rate: {optimizer.param_groups[0]['lr']}")
    train_one_epoch(
        net,
        criterion,
        train_dataloader,
        optimizer,
        epoch,
        clip_max_norm,
    )
    loss = test_epoch(epoch, test_dataloader, net, criterion)
    loss_epoch.append(loss)
    lr_scheduler.step(loss)

    is_best = loss < best_loss
    best_loss = min(loss, best_loss)


print(f"finished training in {round(time.time()-start)} seconds")
# Out:
# Learning rate: 0.0001
# Train epoch 0: [0/250 (0%)]	Loss: 7.444 |	MSE loss: 0.029
# Train epoch 0: [160/250 (62%)]	Loss: 3.322 |	MSE loss: 0.013
# Test epoch 0: Average losses:	Loss: 6.194 |	MSE loss: 0.024 |	PSNR: 16.146 |	SSIM: 0.173
#
# Learning rate: 0.0001
# Train epoch 1: [0/250 (0%)]	Loss: 7.415 |	MSE loss: 0.029
# Train epoch 1: [160/250 (62%)]	Loss: 3.527 |	MSE loss: 0.014
# Test epoch 1: Average losses:	Loss: 6.715 |	MSE loss: 0.026 |	PSNR: 15.796 |	SSIM: 0.189
#
# Learning rate: 0.0001
# Train epoch 2: [0/250 (0%)]	Loss: 7.961 |	MSE loss: 0.031
# Train epoch 2: [160/250 (62%)]	Loss: 6.136 |	MSE loss: 0.024
# Test epoch 2: Average losses:	Loss: 4.634 |	MSE loss: 0.018 |	PSNR: 17.407 |	SSIM: 0.228
#
# Learning rate: 0.0001
# Train epoch 3: [0/250 (0%)]	Loss: 2.990 |	MSE loss: 0.012
# Train epoch 3: [160/250 (62%)]	Loss: 4.266 |	MSE loss: 0.017
# Test epoch 3: Average losses:	Loss: 4.373 |	MSE loss: 0.017 |	PSNR: 17.660 |	SSIM: 0.251
#
# Learning rate: 0.0001
# Train epoch 4: [0/250 (0%)]	Loss: 3.215 |	MSE loss: 0.013
# Train epoch 4: [160/250 (62%)]	Loss: 3.978 |	MSE loss: 0.016
# Test epoch 4: Average losses:	Loss: 5.496 |	MSE loss: 0.022 |	PSNR: 16.666 |	SSIM: 0.246
#
# Learning rate: 0.0001
# Train epoch 5: [0/250 (0%)]	Loss: 3.932 |	MSE loss: 0.015
# Train epoch 5: [160/250 (62%)]	Loss: 6.614 |	MSE loss: 0.026
# Test epoch 5: Average losses:	Loss: 4.698 |	MSE loss: 0.018 |	PSNR: 17.352 |	SSIM: 0.231
#
# Learning rate: 0.0001
# Train epoch 6: [0/250 (0%)]	Loss: 3.886 |	MSE loss: 0.015
# Train epoch 6: [160/250 (62%)]	Loss: 3.579 |	MSE loss: 0.014
# Test epoch 6: Average losses:	Loss: 3.705 |	MSE loss: 0.015 |	PSNR: 18.378 |	SSIM: 0.259
#
# Learning rate: 0.0001
# Train epoch 7: [0/250 (0%)]	Loss: 2.272 |	MSE loss: 0.009
# Train epoch 7: [160/250 (62%)]	Loss: 5.820 |	MSE loss: 0.023
# Test epoch 7: Average losses:	Loss: 3.999 |	MSE loss: 0.016 |	PSNR: 18.049 |	SSIM: 0.272
#
# Learning rate: 0.0001
# Train epoch 8: [0/250 (0%)]	Loss: 4.672 |	MSE loss: 0.018
# Train epoch 8: [160/250 (62%)]	Loss: 3.543 |	MSE loss: 0.014
# Test epoch 8: Average losses:	Loss: 3.143 |	MSE loss: 0.012 |	PSNR: 19.092 |	SSIM: 0.325
#
# Learning rate: 0.0001
# Train epoch 9: [0/250 (0%)]	Loss: 2.230 |	MSE loss: 0.009
# Train epoch 9: [160/250 (62%)]	Loss: 2.617 |	MSE loss: 0.010
# Test epoch 9: Average losses:	Loss: 3.177 |	MSE loss: 0.012 |	PSNR: 19.050 |	SSIM: 0.344
#
# finished training in 214 seconds

# %%
def plotloss(epochs,loss_epoch):

    xs = range(1, epochs + 1)
    ys = loss_epoch
    y = []
    for i in ys:
        y.append(i.cpu().detach().numpy())


    # plot
    plt.figure(figsize=(10, 5))
    plt.plot(xs, y, marker='o', linestyle='-', color='b')
    plt.title('Epoch vs. Average Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Average Loss')
    plt.grid(True)
    plt.show()

plotloss(10,loss_epoch)

# %% [markdown]
# Your code here:

# %% [markdown]
# ## 1.4 Tune hyper parameters and complete corresponding analysis

# %%
lr = [1e-3, 1e-4, 1e-5]
epochs = [10, 20, 30]
nm = [[32,48], [64,96], [128,192]]

class new_net(Network):
    def __init__(self, N, M, lr, epoch, init_weights=True, **kwargs):
        super().__init__(N, M, **kwargs)
        self.lr = lr
        self.epoch = epoch
        self.N, self.M = N, M
        self.loss_epoch = []

    def __str__(self) -> str:
        return f'N: {self.N}, M: {self.M}, lr: {self.lr}, epoch: {self.epoch}' + super().__str__()
    
    def update_loss(self, loss):
        self.loss_epoch.append(loss)

def new_test_epoch(epoch, test_dataloader, model, criterion,last_epoch):
    model.eval()
    device = next(model.parameters()).device

    loss = AverageMeter()
    mse_loss = AverageMeter()
    psnr = AverageMeter()
    ssim_avg = AverageMeter()

    with torch.no_grad():
        for d in test_dataloader:
            d = d.to(device)
            out_net = model(d)
            d_out = out_net['x_hat']
            out_criterion = criterion(out_net, d)

            loss.update(out_criterion["loss"])
            mse_loss.update(out_criterion["mse_loss"])
            psnr.update(PSNR(d_out, d))
            ssim_avg.update(ssim(d * 255, d_out * 255, data_range=255, size_average=True))

    if 1:
        print(
            f"Model with {model.epoch} epochs, {model.lr} learning rate, {model.N} N, {model.M} M Test epoch {epoch}: Average losses:"
            f"\tLoss: {loss.avg:.3f} |"
            f"\tMSE loss: {mse_loss.avg:.3f} |"
            f"\tPSNR: {psnr.avg:.3f} |"
            f"\tSSIM: {ssim_avg.avg:.3f}\n"
        )
    return loss.avg

def train_one_epoch_withoutprint(
    model, criterion, train_dataloader, optimizer, epoch, clip_max_norm
):
    model.train()
    device = next(model.parameters()).device

    for i, d in enumerate(train_dataloader):
        d = d.to(device)

        optimizer.zero_grad()

        out_net = model(d)

        out_criterion = criterion(out_net, d)
        out_criterion["loss"].backward()
        if clip_max_norm > 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), clip_max_norm)
        optimizer.step()

def new_plotloss(newnet):

    xs = range(1, newnet.epoch + 1)

    ys = newnet.loss_epoch
    y = []
    for i in ys:
        y.append(i.cpu().detach().numpy())


    # plot
    plt.figure(figsize=(10, 5))
    plt.plot(xs, y, marker='o', linestyle='-', color='b')
    plt.title(f'Epoch vs. Average Loss with {newnet.epoch} epochs, {newnet.lr} learning rate, {newnet.N} N, {newnet.M} M')
    plt.xlabel('Epoch')
    plt.ylabel('Average Loss')
    plt.grid(True)
    plt.show()

def configure_optimizers_sgd(net, learning_rate):

    optimizer = optim.SGD(
        net.parameters(),
        lr=learning_rate,
        momentum=0.9
    )

    return optimizer


nets1,nets2,nets3 = [],[],[]
nets1sgd,nets2sgd,nets3sgd = [],[],[]
i = 0
while i < 3:
    j = 0
    while j < 3:
        k = 0
        while k < 3:
            net = new_net(nm[i][0], nm[i][1], lr[j], epochs[k]).to(device)
            if i == 0:
                nets1.append(net)
                nets1sgd.append(net)
            elif i == 1:
                nets2.append(net)
                nets2sgd.append(net)
            else:
                nets3.append(net)
                nets3sgd.append(net)
            k += 1
        j += 1
    i += 1


all_nets = [nets1,nets2,nets3,nets1sgd,nets2sgd,nets3sgd]

def train_one_set(nets):
    for net in nets:
        optimizer = configure_optimizers(net, net.lr)
        lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
    #     print(f"Learning rate: {optimizer.param_groups[0]['lr']}")
        for epoch in range(0, net.epoch):
            train_one_epoch_withoutprint(
                net,
                criterion,
                train_dataloader,
                optimizer,
                epoch,
                clip_max_norm,
            )
            loss = new_test_epoch(epoch, test_dataloader, net, criterion,epoch==net.epoch-1)
            net.loss_epoch.append(loss)
            lr_scheduler.step(loss)

            is_best = loss < best_loss
            best_loss = min(loss, best_loss)
        new_plotloss(net)

import multiprocessing
process = []
for nets in all_nets:
    p = multiprocessing.Process(target=train_one_set, args=(nets,))
    process.append(p)
    p.start()

for p in process:
    p.join()

# %% [markdown]
# ## 1.5 Quantization

# %%
# ###################################################
# a baseline model

def conv(in_channels, out_channels, kernel_size=5, stride=2):
    return nn.Conv2d(
        in_channels,
        out_channels,
        kernel_size=kernel_size,
        stride=stride,
        padding=kernel_size // 2,
    )


def deconv(in_channels, out_channels, kernel_size=5, stride=2):
    return nn.ConvTranspose2d(
        in_channels,
        out_channels,
        kernel_size=kernel_size,
        stride=stride,
        output_padding=stride - 1,
        padding=kernel_size // 2,
    )




class Quan_Network(nn.Module):

    def __init__(self, N, M, init_weights=True, **kwargs):
        super().__init__(**kwargs)

        self.g_a = nn.Sequential(
            conv(3, N),
            conv(N, N),
            conv(N, N),
            conv(N, M),
        )

        self.g_s = nn.Sequential(
            deconv(M, N),
            deconv(N, N),
            deconv(N, N),
            deconv(N, 3),
        )

        self.N = N
        self.M = M

        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        y = self.g_a(x)
        x_hat = self.g_s(y)

        return {
            "x_hat": x_hat,
        }

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def compress(self, x):
        y = self.g_a(x)
        quantized, self.max_val, self.min_val = self.quantize(y)
        return quantized

    def decompress(self, quantized):
        y_hat = self.dequantize(quantized, self.max_val, self.min_val)
        x_hat = self.g_s(y_hat).clamp_(0, 1)
        return {"x_hat": x_hat}
    
    def quantize(self, y, levels=256):
        max_val = y.max()
        min_val = y.min()
        quantized = torch.floor((y - min_val) / (max_val - min_val) * (levels - 1))
        return quantized, max_val, min_val

    def dequantize(self, quantized, max_val, min_val, levels=256):
        y_hat = quantized * (max_val - min_val) / (levels - 1) + min_val
        return y_hat

# %%
net = Quan_Network(128,192)
net = net.to(device)
import random
dataset = 'C:\somethings\Kevin' # Modify this if you change the path
test_dataset = ImageFolder(dataset, split="valid", transform=transforms.ToTensor())
image = test_dataset[random.randint(0,10)].unsqueeze(0).to(device)
net.load_state_dict(torch.load('checkpoint_best_loss.pth.tar', map_location=device)["state_dict"])
predicted = net(image)['x_hat'].squeeze(0).detach()
compressed = net.compress(image)
decompressed = net.decompress(compressed)['x_hat'][0]

print('compression ratio: compressed/original {}'.format(compressed.numel() / image.numel()))
fig, axes = plt.subplots(1,3)
axes[0].imshow(image.squeeze(0).cpu().permute(1, 2, 0))
axes[0].axis('off')
axes[0].set_title('original')
axes[1].imshow(predicted.cpu().permute(1, 2, 0))
axes[1].axis('off')
axes[1].set_title('compressed-decoded')
axes[2].imshow(decompressed.cpu().detach().permute(1, 2, 0))
axes[2].axis('off')
axes[2].set_title('decompressed')
# Out:
# compression ratio: compressed/original 0.252014652014652
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'decompressed')

# %%
print("training on", device)
optimizer = configure_optimizers(net, 1e-4)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
criterion = Loss()

last_epoch = 0


loss_epoch = list()
start = time.time()
for epoch in range(last_epoch, 30):
    print(f"Learning rate: {optimizer.param_groups[0]['lr']}")
    train_one_epoch(
        net,
        criterion,
        train_dataloader,
        optimizer,
        epoch,
        clip_max_norm,
    )
    loss = test_epoch(epoch, test_dataloader, net, criterion)
    loss_epoch.append(loss)
    lr_scheduler.step(loss)

    is_best = loss < best_loss
    best_loss = min(loss, best_loss)

plotloss(30,loss_epoch)


print(f"finished training in {round(time.time()-start)} seconds")
# Out:
# training on cuda
# Learning rate: 0.0001
# Train epoch 0: [0/250 (0%)]	Loss: 5.660 |	MSE loss: 0.022
# Train epoch 0: [160/250 (62%)]	Loss: 5.891 |	MSE loss: 0.023
# Test epoch 0: Average losses:	Loss: 8.314 |	MSE loss: 0.033 |	PSNR: 14.871 |	SSIM: 0.130
#
# Learning rate: 0.0001
# Train epoch 1: [0/250 (0%)]	Loss: 6.382 |	MSE loss: 0.025
# Train epoch 1: [160/250 (62%)]	Loss: 6.477 |	MSE loss: 0.025
# Test epoch 1: Average losses:	Loss: 6.068 |	MSE loss: 0.024 |	PSNR: 16.235 |	SSIM: 0.158
#
# Learning rate: 0.0001
# Train epoch 2: [0/250 (0%)]	Loss: 5.634 |	MSE loss: 0.022
# Train epoch 2: [160/250 (62%)]	Loss: 5.239 |	MSE loss: 0.021
# Test epoch 2: Average losses:	Loss: 5.277 |	MSE loss: 0.021 |	PSNR: 16.843 |	SSIM: 0.181
#
# Learning rate: 0.0001
# Train epoch 3: [0/250 (0%)]	Loss: 2.864 |	MSE loss: 0.011
# Train epoch 3: [160/250 (62%)]	Loss: 3.774 |	MSE loss: 0.015
# Test epoch 3: Average losses:	Loss: 4.742 |	MSE loss: 0.019 |	PSNR: 17.307 |	SSIM: 0.210
#
# Learning rate: 0.0001
# Train epoch 4: [0/250 (0%)]	Loss: 3.197 |	MSE loss: 0.013
# Train epoch 4: [160/250 (62%)]	Loss: 4.687 |	MSE loss: 0.018
# Test epoch 4: Average losses:	Loss: 4.456 |	MSE loss: 0.017 |	PSNR: 17.576 |	SSIM: 0.235
#
# Learning rate: 0.0001
# Train epoch 5: [0/250 (0%)]	Loss: 3.152 |	MSE loss: 0.012
# Train epoch 5: [160/250 (62%)]	Loss: 2.965 |	MSE loss: 0.012
# Test epoch 5: Average losses:	Loss: 4.667 |	MSE loss: 0.018 |	PSNR: 17.378 |	SSIM: 0.228
#
# Learning rate: 0.0001
# Train epoch 6: [0/250 (0%)]	Loss: 3.576 |	MSE loss: 0.014
# Train epoch 6: [160/250 (62%)]	Loss: 3.127 |	MSE loss: 0.012
# Test epoch 6: Average losses:	Loss: 3.775 |	MSE loss: 0.015 |	PSNR: 18.298 |	SSIM: 0.267
#
# Learning rate: 0.0001
# Train epoch 7: [0/250 (0%)]	Loss: 2.470 |	MSE loss: 0.010
# Train epoch 7: [160/250 (62%)]	Loss: 4.000 |	MSE loss: 0.016
# Test epoch 7: Average losses:	Loss: 3.323 |	MSE loss: 0.013 |	PSNR: 18.851 |	SSIM: 0.287
#
# Learning rate: 0.0001
# Train epoch 8: [0/250 (0%)]	Loss: 2.536 |	MSE loss: 0.010
# Train epoch 8: [160/250 (62%)]	Loss: 2.740 |	MSE loss: 0.011
# Test epoch 8: Average losses:	Loss: 3.263 |	MSE loss: 0.013 |	PSNR: 18.931 |	SSIM: 0.315
#
# Learning rate: 0.0001
# Train epoch 9: [0/250 (0%)]	Loss: 2.242 |	MSE loss: 0.009
# Train epoch 9: [160/250 (62%)]	Loss: 2.068 |	MSE loss: 0.008
# Test epoch 9: Average losses:	Loss: 3.011 |	MSE loss: 0.012 |	PSNR: 19.281 |	SSIM: 0.352
#
# Learning rate: 0.0001
# Train epoch 10: [0/250 (0%)]	Loss: 5.009 |	MSE loss: 0.020
# Train epoch 10: [160/250 (62%)]	Loss: 1.871 |	MSE loss: 0.007
# Test epoch 10: Average losses:	Loss: 2.682 |	MSE loss: 0.011 |	PSNR: 19.782 |	SSIM: 0.370
#
# Learning rate: 0.0001
# Train epoch 11: [0/250 (0%)]	Loss: 2.554 |	MSE loss: 0.010
# Train epoch 11: [160/250 (62%)]	Loss: 2.070 |	MSE loss: 0.008
# Test epoch 11: Average losses:	Loss: 2.825 |	MSE loss: 0.011 |	PSNR: 19.560 |	SSIM: 0.378
#
# Learning rate: 0.0001
# Train epoch 12: [0/250 (0%)]	Loss: 1.898 |	MSE loss: 0.007
# Train epoch 12: [160/250 (62%)]	Loss: 3.234 |	MSE loss: 0.013
# Test epoch 12: Average losses:	Loss: 2.745 |	MSE loss: 0.011 |	PSNR: 19.685 |	SSIM: 0.379
#
# Learning rate: 0.0001
# Train epoch 13: [0/250 (0%)]	Loss: 2.054 |	MSE loss: 0.008
# Train epoch 13: [160/250 (62%)]	Loss: 2.239 |	MSE loss: 0.009
# Test epoch 13: Average losses:	Loss: 2.499 |	MSE loss: 0.010 |	PSNR: 20.088 |	SSIM: 0.403
#
# Learning rate: 0.0001
# Train epoch 14: [0/250 (0%)]	Loss: 2.468 |	MSE loss: 0.010
# Train epoch 14: [160/250 (62%)]	Loss: 2.837 |	MSE loss: 0.011
# Test epoch 14: Average losses:	Loss: 2.590 |	MSE loss: 0.010 |	PSNR: 19.934 |	SSIM: 0.382
#
# Learning rate: 0.0001
# Train epoch 15: [0/250 (0%)]	Loss: 2.385 |	MSE loss: 0.009
# Train epoch 15: [160/250 (62%)]	Loss: 1.956 |	MSE loss: 0.008
# Test epoch 15: Average losses:	Loss: 2.300 |	MSE loss: 0.009 |	PSNR: 20.450 |	SSIM: 0.414
#
# Learning rate: 0.0001
# Train epoch 16: [0/250 (0%)]	Loss: 1.628 |	MSE loss: 0.006
# Train epoch 16: [160/250 (62%)]	Loss: 2.097 |	MSE loss: 0.008
# Test epoch 16: Average losses:	Loss: 2.197 |	MSE loss: 0.009 |	PSNR: 20.647 |	SSIM: 0.425
#
# Learning rate: 0.0001
# Train epoch 17: [0/250 (0%)]	Loss: 2.248 |	MSE loss: 0.009
# Train epoch 17: [160/250 (62%)]	Loss: 1.743 |	MSE loss: 0.007
# Test epoch 17: Average losses:	Loss: 2.161 |	MSE loss: 0.008 |	PSNR: 20.724 |	SSIM: 0.449
#
# Learning rate: 0.0001
# Train epoch 18: [0/250 (0%)]	Loss: 1.329 |	MSE loss: 0.005
# Train epoch 18: [160/250 (62%)]	Loss: 1.565 |	MSE loss: 0.006
# Test epoch 18: Average losses:	Loss: 2.111 |	MSE loss: 0.008 |	PSNR: 20.821 |	SSIM: 0.457
#
# Learning rate: 0.0001
# Train epoch 19: [0/250 (0%)]	Loss: 1.410 |	MSE loss: 0.006
# Train epoch 19: [160/250 (62%)]	Loss: 2.889 |	MSE loss: 0.011
# Test epoch 19: Average losses:	Loss: 2.098 |	MSE loss: 0.008 |	PSNR: 20.847 |	SSIM: 0.455
#
# Learning rate: 0.0001
# Train epoch 20: [0/250 (0%)]	Loss: 2.275 |	MSE loss: 0.009
# Train epoch 20: [160/250 (62%)]	Loss: 2.151 |	MSE loss: 0.008
# Test epoch 20: Average losses:	Loss: 1.976 |	MSE loss: 0.008 |	PSNR: 21.109 |	SSIM: 0.480
#
# Learning rate: 0.0001
# Train epoch 21: [0/250 (0%)]	Loss: 2.736 |	MSE loss: 0.011
# Train epoch 21: [160/250 (62%)]	Loss: 2.595 |	MSE loss: 0.010
# Test epoch 21: Average losses:	Loss: 1.891 |	MSE loss: 0.007 |	PSNR: 21.300 |	SSIM: 0.432
#
# Learning rate: 0.0001
# Train epoch 22: [0/250 (0%)]	Loss: 0.970 |	MSE loss: 0.004
# Train epoch 22: [160/250 (62%)]	Loss: 2.066 |	MSE loss: 0.008
# Test epoch 22: Average losses:	Loss: 1.858 |	MSE loss: 0.007 |	PSNR: 21.378 |	SSIM: 0.467
#
# Learning rate: 0.0001
# Train epoch 23: [0/250 (0%)]	Loss: 1.641 |	MSE loss: 0.006
# Train epoch 23: [160/250 (62%)]	Loss: 0.490 |	MSE loss: 0.002
# Test epoch 23: Average losses:	Loss: 1.785 |	MSE loss: 0.007 |	PSNR: 21.554 |	SSIM: 0.488
#
# Learning rate: 0.0001
# Train epoch 24: [0/250 (0%)]	Loss: 1.762 |	MSE loss: 0.007
# Train epoch 24: [160/250 (62%)]	Loss: 2.043 |	MSE loss: 0.008
# Test epoch 24: Average losses:	Loss: 1.781 |	MSE loss: 0.007 |	PSNR: 21.564 |	SSIM: 0.503
#
# Learning rate: 0.0001
# Train epoch 25: [0/250 (0%)]	Loss: 1.493 |	MSE loss: 0.006
# Train epoch 25: [160/250 (62%)]	Loss: 1.509 |	MSE loss: 0.006
# Test epoch 25: Average losses:	Loss: 1.699 |	MSE loss: 0.007 |	PSNR: 21.764 |	SSIM: 0.510
#
# Learning rate: 0.0001
# Train epoch 26: [0/250 (0%)]	Loss: 1.515 |	MSE loss: 0.006
# Train epoch 26: [160/250 (62%)]	Loss: 0.555 |	MSE loss: 0.002
# Test epoch 26: Average losses:	Loss: 1.648 |	MSE loss: 0.006 |	PSNR: 21.900 |	SSIM: 0.540
#
# Learning rate: 0.0001
# Train epoch 27: [0/250 (0%)]	Loss: 1.776 |	MSE loss: 0.007
# Train epoch 27: [160/250 (62%)]	Loss: 1.734 |	MSE loss: 0.007
# Test epoch 27: Average losses:	Loss: 1.529 |	MSE loss: 0.006 |	PSNR: 22.225 |	SSIM: 0.554
#
# Learning rate: 0.0001
# Train epoch 28: [0/250 (0%)]	Loss: 1.290 |	MSE loss: 0.005
# Train epoch 28: [160/250 (62%)]	Loss: 1.772 |	MSE loss: 0.007
# Test epoch 28: Average losses:	Loss: 1.632 |	MSE loss: 0.006 |	PSNR: 21.942 |	SSIM: 0.547
#
# Learning rate: 0.0001
# Train epoch 29: [0/250 (0%)]	Loss: 1.226 |	MSE loss: 0.005
# Train epoch 29: [160/250 (62%)]	Loss: 2.383 |	MSE loss: 0.009
# Test epoch 29: Average losses:	Loss: 1.529 |	MSE loss: 0.006 |	PSNR: 22.224 |	SSIM: 0.550
# finished training in 664 seconds

# %%
dataset = 'C:\somethings\Kevin' # Modify this if you change the path
test_dataset = ImageFolder(dataset, split="valid", transform=transforms.ToTensor())
image = test_dataset[random.randint(10,20)].unsqueeze(0).to(device)
net.load_state_dict(torch.load('checkpoint_best_loss.pth.tar', map_location=device)["state_dict"])
predicted = net(image)['x_hat'].squeeze(0).detach()
pred = net.compress(image)
decompressed = net.decompress(pred)['x_hat'][0]
print('compression ratio: compressed/original {}'.format(pred.numel() / image.numel()))

fig, axes = plt.subplots(1,3)
axes[0].imshow(image.squeeze(0).cpu().permute(1, 2, 0))
axes[0].axis('off')
axes[0].set_title('original')
axes[1].imshow(predicted.cpu().permute(1, 2, 0))
axes[1].axis('off')
axes[1].set_title('compressed-decoded')
axes[2].imshow(decompressed.cpu().detach().permute(1, 2, 0))
axes[2].axis('off')
axes[2].set_title('decompressed')
# Out:
# compression ratio: compressed/original 0.252014652014652
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'decompressed')
